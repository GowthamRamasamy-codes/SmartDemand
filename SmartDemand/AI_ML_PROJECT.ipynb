# %%
import pandas as pd
import requests
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
api_key = 'f5ce57ac083b09535b11cec55b027465'

# %%
def load_data(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

# %%
def get_weather_data(location):
    try:
        url = f"https://api.openweathermap.org/data/2.5/forecast?q={location}&units=imperial&appid={api_key}"
        response = requests.get(url)
        if response.status_code == 200:
            return response.json()
        else:
            print(f"Error fetching weather data. Status code: {response.status_code}")
            return None
    except Exception as e:
        print(f"Error fetching weather data: {e}")
        return None

# %%
def train_demand_models(data):
    if data is None or 'Date' not in data.columns:
        print("Error: Required columns not found in the dataset.")
        return None, None
    
    X_rf = data[['Date']].copy()
    y_rf = data.drop(columns=['Date'])
    
    try:
        X_rf['Date'] = pd.to_datetime(X_rf['Date'], infer_datetime_format=True)
    except ValueError:
        print("Error: Unable to infer datetime format. Please check the Date column in your dataset.")
        return None, None
    
    X_rf['DayOfYear'] = X_rf['Date'].dt.dayofyear
    
    X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_rf[['DayOfYear']], y_rf, test_size=0.2, random_state=42)
    
    models_rf = {}
    for fruit in y_rf.columns:
        model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
        model_rf.fit(X_train_rf, y_train_rf[fruit])
        models_rf[fruit] = model_rf
        
        y_pred_rf = model_rf.predict(X_test_rf)
        r2_rf = r2_score(y_test_rf[fruit], y_pred_rf)
        mse_rf = mean_squared_error(y_test_rf[fruit], y_pred_rf)
        
        print(f"RandomForestRegressor Model trained successfully for {fruit}. R2: {r2_rf:.2f}, MSE: {mse_rf:.2f}")
    
    X_ml = X_rf[['DayOfYear']].copy()
    models_ml = {}
    for fruit in y_rf.columns:
        y_ml = data[fruit]
        X_train_ml, X_test_ml, y_train_ml, y_test_ml = train_test_split(X_ml, y_ml, test_size=0.2, random_state=42)
        
        model_ml = LinearRegression()
        model_ml.fit(X_train_ml, y_train_ml)
        
        y_pred_ml = model_ml.predict(X_test_ml)
        r2_ml = r2_score(y_test_ml, y_pred_ml)
        mse_ml = mean_squared_error(y_test_ml, y_pred_ml)
        
        models_ml[fruit] = model_ml
        
        print(f"ML Model (LinearRegression) trained successfully for {fruit}. R2: {r2_ml:.2f}, MSE: {mse_ml:.2f}")
    
    return models_rf, models_ml

# %%
def predict_demand(models_rf, models_ml, location):
    try:
        weather_data = get_weather_data(location)
        if weather_data is None or 'list' not in weather_data:
            print(f"No weather data found for {location}. Predicting demand without weather considerations.")
            return None
        
        forecast = weather_data['list']
        
        output = []
        rainy_day_predicted = False
        
        output.append(f"Weather in {location} (Indian Standard Time):")
        
        time_slots = ['3:00 AM (Night)', '9:00 AM (Morning)', '3:00 PM (Afternoon)', '9:00 PM (Evening)']
        
        previous_day = None
        for i, entry in enumerate(forecast):
            date_time = datetime.strptime(entry['dt_txt'], '%Y-%m-%d %H:%M:%S')
            day_name = date_time.strftime('%A')
            date_str = date_time.strftime('%Y-%m-%d')
            
            if previous_day != date_str:
                output.append(f"{day_name}, {date_str}:")
                previous_day = date_str
            
            slot = time_slots[i % 4]
            
            weather_description = entry['weather'][0]['description']
            temperature = entry['main']['temp']
            feels_like = entry['main']['feels_like']
            humidity = entry['main']['humidity']
            pressure = entry['main']['pressure']
            wind_speed = entry['wind']['speed']
            wind_direction = entry['wind']['deg']
            
            output.append(f"{slot}:")
            output.append(f"Description: {weather_description}")
            output.append(f"Temperature: {temperature}°F")
            output.append(f"Feels Like: {feels_like}°F")
            output.append(f"Humidity: {humidity}%")
            output.append(f"Pressure: {pressure} hPa")
            output.append(f"Wind Speed: {wind_speed} mph")
            output.append(f"Wind Direction: {wind_direction}°")
            output.append("")
            
            if 'rain' in weather_description.lower() or 'thunderstorm' in weather_description.lower() or 'drizzle' in weather_description.lower():
                rainy_day_predicted = True
                output.append(f"⛈️ Rainy period detected: {day_name}, {slot}")
        
        if not rainy_day_predicted:
            output.append("No rainy days predicted in the upcoming forecast.")
            print("\n".join(output))
            
            print("\nPredicted Demand for Sunny Days:")
            for fruit, model_ml in models_ml.items():
                future_date_str = forecast[0]['dt_txt'][:10]
                dayofyear = pd.to_datetime(future_date_str, format='%Y-%m-%d').dayofyear
                
                predicted_demand_ml = model_ml.predict([[dayofyear]])[0]
                output.append(f"{future_date_str}: {fruit} (ML Model): {predicted_demand_ml:.2f} kgs")
            
            print("\n".join(output))
            return None
        
        output.append("Predicted Demand for Rainy Days (Indian Standard Time):")
        for fruit, model_rf in models_rf.items():
            future_date_str = forecast[0]['dt_txt'][:10]
            dayofyear = pd.to_datetime(future_date_str, format='%Y-%m-%d').dayofyear
            
            predicted_demand_rf = model_rf.predict([[dayofyear]])[0] * 1.5
            output.append(f"{future_date_str}: {fruit} (RF Model): {predicted_demand_rf:.2f} kgs")
        output.append("")

        output.append("Predicted Demand for sunny Days (Indian Standard Time):")
        for fruit, model_rf in models_rf.items():
            future_date_str = forecast[0]['dt_txt'][:10]
            dayofyear = pd.to_datetime(future_date_str, format='%Y-%m-%d').dayofyear
            
            predicted_demand_rf = model_rf.predict([[dayofyear]])[0] * 1
            output.append(f"{future_date_str}: {fruit} (RF Model): {predicted_demand_rf:.2f} kgs")
        
        output.append("")
        output.append("Recorded Rainy Climate:")
        for entry in forecast:
            if 'rain' in entry['weather'][0]['description'].lower():
                date_time = datetime.strptime(entry['dt_txt'], '%Y-%m-%d %H:%M:%S')
                day_name = date_time.strftime('%A')
                slot = time_slots[date_time.hour // 6]
                output.append(f"{day_name}, {date_time.strftime('%Y-%m-%d')} at {slot}")
        
        print("\n".join(output))
        
        return output
    
    except Exception as e:
        print(f"Error predicting demand: {e}")
        return None

# %%
if __name__ == "__main__":
    file_path = 'fruit_data.csv'
    
    data = load_data(file_path)
    
    models_rf, models_ml = train_demand_models(data)
    
    if models_rf and models_ml:
        user_location = input("Enter the required location: ")
        predict_demand(models_rf, models_ml, user_location)
# Out:
# C:\Users\Gowtham\AppData\Local\Temp\ipykernel_13816\2217599898.py:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   X_rf['Date'] = pd.to_datetime(X_rf['Date'], infer_datetime_format=True)
# RandomForestRegressor Model trained successfully for Apples. R2: 0.02, MSE: 5.22
# RandomForestRegressor Model trained successfully for Bananas. R2: -0.15, MSE: 4.07
# RandomForestRegressor Model trained successfully for Oranges. R2: -0.31, MSE: 1.70
# RandomForestRegressor Model trained successfully for Grapes. R2: 0.00, MSE: 0.93
# ML Model (LinearRegression) trained successfully for Apples. R2: -0.01, MSE: 5.36
# ML Model (LinearRegression) trained successfully for Bananas. R2: -0.04, MSE: 3.66
# ML Model (LinearRegression) trained successfully for Oranges. R2: -0.01, MSE: 1.31
# ML Model (LinearRegression) trained successfully for Grapes. R2: -0.02, MSE: 0.95
# Weather in coimbatore (Indian Standard Time):
# Sunday, 2024-06-16:
# 3:00 AM (Night):
# Description: few clouds
# Temperature: 90.54°F
# Feels Like: 99.23°F
# Humidity: 57%
# Pressure: 1009 hPa
# Wind Speed: 15.95 mph
# Wind Direction: 240°
#
# 9:00 AM (Morning):
# Description: scattered clouds
# Temperature: 86.67°F
# Feels Like: 91.63°F
# Humidity: 58%
# Pressure: 1008 hPa
# Wind Speed: 15.48 mph
# Wind Direction: 243°
#
# 3:00 PM (Afternoon):
# Description: light rain
# Temperature: 77.94°F
# Feels Like: 78.96°F
# Humidity: 75%
# Pressure: 1009 hPa
# Wind Speed: 12.68 mph
# Wind Direction: 245°
#
# ⛈️ Rainy period detected: Sunday, 3:00 PM (Afternoon)
# 9:00 PM (Evening):
# Description: light rain
# Temperature: 75.49°F
# Feels Like: 76.59°F
# Humidity: 82%
# Pressure: 1009 hPa
# Wind Speed: 10.38 mph
# Wind Direction: 242°
#
# ⛈️ Rainy period detected: Sunday, 9:00 PM (Evening)
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 74.34°F
# Feels Like: 75.47°F
# Humidity: 85%
# Pressure: 1007 hPa
# Wind Speed: 8.03 mph
# Wind Direction: 243°
#
# Monday, 2024-06-17:
# 9:00 AM (Morning):
# Description: overcast clouds
# Temperature: 74.34°F
# Feels Like: 75.36°F
# Humidity: 83%
# Pressure: 1008 hPa
# Wind Speed: 8.59 mph
# Wind Direction: 257°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 80.6°F
# Feels Like: 83.08°F
# Humidity: 64%
# Pressure: 1010 hPa
# Wind Speed: 10.58 mph
# Wind Direction: 250°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 87.12°F
# Feels Like: 90.63°F
# Humidity: 53%
# Pressure: 1009 hPa
# Wind Speed: 11.92 mph
# Wind Direction: 239°
#
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 89.24°F
# Feels Like: 93.61°F
# Humidity: 51%
# Pressure: 1007 hPa
# Wind Speed: 14.32 mph
# Wind Direction: 234°
#
# 9:00 AM (Morning):
# Description: light rain
# Temperature: 82.83°F
# Feels Like: 86.56°F
# Humidity: 64%
# Pressure: 1008 hPa
# Wind Speed: 15.21 mph
# Wind Direction: 241°
#
# ⛈️ Rainy period detected: Monday, 9:00 AM (Morning)
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 77.54°F
# Feels Like: 78.62°F
# Humidity: 77%
# Pressure: 1009 hPa
# Wind Speed: 13.29 mph
# Wind Direction: 249°
#
# 9:00 PM (Evening):
# Description: light rain
# Temperature: 76.15°F
# Feels Like: 77.27°F
# Humidity: 81%
# Pressure: 1009 hPa
# Wind Speed: 12.46 mph
# Wind Direction: 248°
#
# ⛈️ Rainy period detected: Monday, 9:00 PM (Evening)
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 74.59°F
# Feels Like: 75.69°F
# Humidity: 84%
# Pressure: 1008 hPa
# Wind Speed: 10.98 mph
# Wind Direction: 245°
#
# Tuesday, 2024-06-18:
# 9:00 AM (Morning):
# Description: overcast clouds
# Temperature: 73.76°F
# Feels Like: 74.88°F
# Humidity: 86%
# Pressure: 1009 hPa
# Wind Speed: 10.16 mph
# Wind Direction: 247°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 79.61°F
# Feels Like: 79.61°F
# Humidity: 70%
# Pressure: 1010 hPa
# Wind Speed: 11.3 mph
# Wind Direction: 246°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 86.9°F
# Feels Like: 90.25°F
# Humidity: 53%
# Pressure: 1009 hPa
# Wind Speed: 13.31 mph
# Wind Direction: 242°
#
# 3:00 AM (Night):
# Description: broken clouds
# Temperature: 88.86°F
# Feels Like: 92.53°F
# Humidity: 50%
# Pressure: 1007 hPa
# Wind Speed: 16.58 mph
# Wind Direction: 242°
#
# 9:00 AM (Morning):
# Description: light rain
# Temperature: 82.8°F
# Feels Like: 86.04°F
# Humidity: 62%
# Pressure: 1007 hPa
# Wind Speed: 16.6 mph
# Wind Direction: 245°
#
# ⛈️ Rainy period detected: Tuesday, 9:00 AM (Morning)
# 3:00 PM (Afternoon):
# Description: light rain
# Temperature: 76.8°F
# Feels Like: 77.94°F
# Humidity: 80%
# Pressure: 1009 hPa
# Wind Speed: 13.58 mph
# Wind Direction: 246°
#
# ⛈️ Rainy period detected: Tuesday, 3:00 PM (Afternoon)
# 9:00 PM (Evening):
# Description: light rain
# Temperature: 75.47°F
# Feels Like: 76.66°F
# Humidity: 84%
# Pressure: 1010 hPa
# Wind Speed: 10.94 mph
# Wind Direction: 242°
#
# ⛈️ Rainy period detected: Tuesday, 9:00 PM (Evening)
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 74.28°F
# Feels Like: 75.54°F
# Humidity: 88%
# Pressure: 1008 hPa
# Wind Speed: 9.93 mph
# Wind Direction: 242°
#
# Wednesday, 2024-06-19:
# 9:00 AM (Morning):
# Description: overcast clouds
# Temperature: 73.53°F
# Feels Like: 74.8°F
# Humidity: 90%
# Pressure: 1008 hPa
# Wind Speed: 8.99 mph
# Wind Direction: 243°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 79.7°F
# Feels Like: 79.7°F
# Humidity: 70%
# Pressure: 1009 hPa
# Wind Speed: 11.01 mph
# Wind Direction: 245°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 87.91°F
# Feels Like: 91.26°F
# Humidity: 51%
# Pressure: 1008 hPa
# Wind Speed: 12.53 mph
# Wind Direction: 240°
#
# 3:00 AM (Night):
# Description: scattered clouds
# Temperature: 89.91°F
# Feels Like: 92.73°F
# Humidity: 46%
# Pressure: 1006 hPa
# Wind Speed: 16.04 mph
# Wind Direction: 242°
#
# 9:00 AM (Morning):
# Description: scattered clouds
# Temperature: 83.77°F
# Feels Like: 86.88°F
# Humidity: 59%
# Pressure: 1006 hPa
# Wind Speed: 16.64 mph
# Wind Direction: 243°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 76.73°F
# Feels Like: 77.81°F
# Humidity: 79%
# Pressure: 1008 hPa
# Wind Speed: 14.79 mph
# Wind Direction: 239°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 74.71°F
# Feels Like: 75.92°F
# Humidity: 86%
# Pressure: 1009 hPa
# Wind Speed: 11.7 mph
# Wind Direction: 239°
#
# 3:00 AM (Night):
# Description: broken clouds
# Temperature: 73.44°F
# Feels Like: 74.62°F
# Humidity: 88%
# Pressure: 1007 hPa
# Wind Speed: 10.27 mph
# Wind Direction: 248°
#
# Thursday, 2024-06-20:
# 9:00 AM (Morning):
# Description: broken clouds
# Temperature: 72.93°F
# Feels Like: 74.1°F
# Humidity: 89%
# Pressure: 1008 hPa
# Wind Speed: 10.02 mph
# Wind Direction: 247°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 78.76°F
# Feels Like: 78.76°F
# Humidity: 71%
# Pressure: 1010 hPa
# Wind Speed: 11.56 mph
# Wind Direction: 247°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 86.9°F
# Feels Like: 89.26°F
# Humidity: 50%
# Pressure: 1009 hPa
# Wind Speed: 13.67 mph
# Wind Direction: 241°
#
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 89.04°F
# Feels Like: 91.31°F
# Humidity: 46%
# Pressure: 1006 hPa
# Wind Speed: 16.11 mph
# Wind Direction: 243°
#
# 9:00 AM (Morning):
# Description: overcast clouds
# Temperature: 83.97°F
# Feels Like: 86.45°F
# Humidity: 56%
# Pressure: 1007 hPa
# Wind Speed: 15.95 mph
# Wind Direction: 239°
#
# 3:00 PM (Afternoon):
# Description: broken clouds
# Temperature: 76.71°F
# Feels Like: 77.76°F
# Humidity: 78%
# Pressure: 1009 hPa
# Wind Speed: 12.75 mph
# Wind Direction: 241°
#
# 9:00 PM (Evening):
# Description: broken clouds
# Temperature: 74.48°F
# Feels Like: 75.58°F
# Humidity: 84%
# Pressure: 1009 hPa
# Wind Speed: 11.52 mph
# Wind Direction: 239°
#
# 3:00 AM (Night):
# Description: overcast clouds
# Temperature: 73.22°F
# Feels Like: 74.34°F
# Humidity: 87%
# Pressure: 1008 hPa
# Wind Speed: 10.51 mph
# Wind Direction: 240°
#
# Friday, 2024-06-21:
# 9:00 AM (Morning):
# Description: overcast clouds
# Temperature: 72.45°F
# Feels Like: 73.58°F
# Humidity: 89%
# Pressure: 1008 hPa
# Wind Speed: 10.11 mph
# Wind Direction: 244°
#
# 3:00 PM (Afternoon):
# Description: overcast clouds
# Temperature: 79.38°F
# Feels Like: 79.38°F
# Humidity: 66%
# Pressure: 1010 hPa
# Wind Speed: 13.04 mph
# Wind Direction: 245°
#
# 9:00 PM (Evening):
# Description: overcast clouds
# Temperature: 81.64°F
# Feels Like: 83.93°F
# Humidity: 60%
# Pressure: 1009 hPa
# Wind Speed: 15.68 mph
# Wind Direction: 242°
#
# Predicted Demand for Rainy Days (Indian Standard Time):
# 2024-06-16: Apples (RF Model): 31.28 kgs
# 2024-06-16: Bananas (RF Model): 18.33 kgs
# 2024-06-16: Oranges (RF Model): 12.77 kgs
# 2024-06-16: Grapes (RF Model): 9.88 kgs
#
# Predicted Demand for sunny Days (Indian Standard Time):
# 2024-06-16: Apples (RF Model): 20.85 kgs
# 2024-06-16: Bananas (RF Model): 12.22 kgs
# 2024-06-16: Oranges (RF Model): 8.51 kgs
# 2024-06-16: Grapes (RF Model): 6.59 kgs
#
# Recorded Rainy Climate:
# Sunday, 2024-06-16 at 3:00 PM (Afternoon)
# Sunday, 2024-06-16 at 9:00 PM (Evening)
# Monday, 2024-06-17 at 3:00 PM (Afternoon)
# Monday, 2024-06-17 at 9:00 PM (Evening)
# Tuesday, 2024-06-18 at 3:00 PM (Afternoon)
# Tuesday, 2024-06-18 at 3:00 PM (Afternoon)
# Tuesday, 2024-06-18 at 9:00 PM (Evening)
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\Gowtham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
